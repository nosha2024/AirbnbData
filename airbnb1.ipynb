# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("/content/gdrive/MyDrive/Reviews.csv")

# %%
df2=pd.read_csv("/content/Listings.csv", nrows=5000)

# %%
df1
# Out:
#          listing_id  review_id        date  reviewer_id
# 0             11798  330265172  2018-09-30     11863072
# 1             15383  330103585  2018-09-30     39147453
# 2             16455  329985788  2018-09-30      1125378
# 3             17919  330016899  2018-09-30    172717984
# 4             26827  329995638  2018-09-30     17542859
# ...             ...        ...         ...          ...
# 5373138    47779342  726766332  2021-01-25    283094516
# 5373139    47823964  727963021  2021-01-31     76411977
# 5373140    47896175  728548625  2021-02-02     71370946
# 5373141    47900451  727399287  2021-01-29    109011160
# 5373142    47998038  730320626  2021-02-11    276790978
#
# [5373143 rows x 4 columns]

# %%
my_df=pd.merge(df1,df2,on='listing_id')

# %%
df2[df2['review_scores_rating']>99]
# Out:
#       listing_id                                               name  \
# 0         281420     Beautiful Flat in le Village Montmartre, Paris
# 1        3705183                         39 mÂ² Paris (Sacre CÅ“ur)
# 2        4082273                Lovely apartment with Terrace, 60m2
# 3        4797344                Cosy studio (close to Eiffel tower)
# 4        4823489   Close to Eiffel Tower - Beautiful flat : 2 rooms
# ...          ...                                                ...
# 4866    36404577  Gorgeous bright apt near MONTMARTRE - Professi...
# 4867    37439444            Appartement T2 renove au coeur de Paris
# 4870    40387842   2 PiÃ¨ces lumineux de 44m2 donnant sur les quais
# 4871    42029878  Lovely apartment near Grands boulevards - Prof...
# 4973     4789109                            Appartement trÃ¨s calme
#
#         host_id  host_since                 host_location  host_response_time  \
# ...

# %%
df2
# Out:
#       listing_id                                              name   host_id  \
# 0         281420    Beautiful Flat in le Village Montmartre, Paris   1466919
# 1        3705183                        39 mÂ² Paris (Sacre CÅ“ur)  10328771
# 2        4082273               Lovely apartment with Terrace, 60m2  19252768
# 3        4797344               Cosy studio (close to Eiffel tower)  10668311
# 4        4823489  Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
# ...          ...                                               ...       ...
# 4995    13665079       Cute little apartment in calm neighbourhood  78413936
# 4996    13905913       Apartment Paris 12e near Bastille and Seine  82441053
# 4997    14146127         Charmant deux piÃ¨ces  au coeur du Marais  33044986
# 4998    15667739            Cute & Cosy apartment in Paris, Nation  61390031
# 4999    16060744           Cosy 2-room appartment, center of Paris  60725339
#
# ...

# %%
my_df.sort_values(by = ['host_since','host_location']).head(10)
# Out:
#        listing_id  review_id        date  reviewer_id  \
# 27843    27461743  325677848  2018-09-20     26562767
# 27844    27461743  403963931  2019-01-22     85713014
# 37422    33367377  558585321  2019-11-03     12634916
# 37423    33367377  561959169  2019-11-10     29092601
# 37424    33367377  583780419  2019-12-29     99827284
# 37425    33367377  467201505  2019-06-10     78168170
# 37426    33367377  443619638  2019-04-26     13521290
# 25880    11371163  139592275  2017-03-26     12565017
# 25881    11371163  317367165  2018-09-02    135263350
# 25882    11371163  368047308  2019-01-06     68691483
#
#                                                 name  host_id  host_since  \
# 27843  Cosy and bright apt with a balcony - Paris 11   225541  2010-09-06
# 27844  Cosy and bright apt with a balcony - Paris 11   225541  2010-09-06
# 37422  Magnifique appartement avec vue sur les toits   248695  2010-09-29
# ...

# %%
my_df
# Out:
#        listing_id  review_id        date  reviewer_id  \
# 0          637100  330102069  2018-09-30     47624868
# 1          637100  332829442  2018-10-06    133976583
# 2          637100  325560448  2018-09-20     40239110
# 3          637100   15812516  2014-07-16     12186229
# 4          637100   21603232  2014-10-20     18776856
# ...           ...        ...         ...          ...
# 39050    41633165  608285574  2020-02-20     75246196
# 39051    41848239  601722444  2020-02-04    127545499
# 39052    41972376  614165173  2020-03-04    330059392
# 39053    42055306  604944825  2020-02-13    197343070
# 39054    43027995  623341285  2020-04-29    342640122
#
#                                                     name    host_id  \
# 0                         Beautiful Loft/Appt Montmartre    2891527
# 1                         Beautiful Loft/Appt Montmartre    2891527
# 2                         Beautiful Loft/Appt Montmartre    2891527
# ...

# %%
df1.drop(4, axis=0)
# Out:
#          listing_id  review_id        date  reviewer_id
# 0             11798  330265172  2018-09-30     11863072
# 1             15383  330103585  2018-09-30     39147453
# 2             16455  329985788  2018-09-30      1125378
# 3             17919  330016899  2018-09-30    172717984
# 5             74561  330089224  2018-09-30    173044789
# ...             ...        ...         ...          ...
# 5373138    47779342  726766332  2021-01-25    283094516
# 5373139    47823964  727963021  2021-01-31     76411977
# 5373140    47896175  728548625  2021-02-02     71370946
# 5373141    47900451  727399287  2021-01-29    109011160
# 5373142    47998038  730320626  2021-02-11    276790978
#
# [5373142 rows x 4 columns]

# %%
df2[df2['review_scores_rating'] > 50]
# Out:
#       listing_id                                              name   host_id  \
# 0         281420    Beautiful Flat in le Village Montmartre, Paris   1466919
# 1        3705183                        39 mÂ² Paris (Sacre CÅ“ur)  10328771
# 2        4082273               Lovely apartment with Terrace, 60m2  19252768
# 3        4797344               Cosy studio (close to Eiffel tower)  10668311
# 4        4823489  Close to Eiffel Tower - Beautiful flat : 2 rooms  24837558
# ...          ...                                               ...       ...
# 4977     5621376                         Apartment at Montparnasse  27224548
# 4978     5812726                 Flat 17eme 45m2- Near Batignolles   9184030
# 4995    13665079       Cute little apartment in calm neighbourhood  78413936
# 4996    13905913       Apartment Paris 12e near Bastille and Seine  82441053
# 4998    15667739            Cute & Cosy apartment in Paris, Nation  61390031
#
# ...

# %%
my_df.query('(`review_scores_rating` > 90) & (`review_scores_accuracy` < 10)')
# Out:
#        listing_id  review_id        date  reviewer_id  \
# 0          637100  330102069  2018-09-30     47624868
# 1          637100  332829442  2018-10-06    133976583
# 2          637100  325560448  2018-09-20     40239110
# 3          637100   15812516  2014-07-16     12186229
# 4          637100   21603232  2014-10-20     18776856
# ...           ...        ...         ...          ...
# 38659    32372584  476043785  2019-06-25    258727660
# 38660    32372584  485061038  2019-07-10    160756920
# 38893    35754830  472681553  2019-06-20     11999100
# 38982    31249092  460481268  2019-05-29      1765737
# 39007    39189332  556670649  2019-10-30    297673338
#
#                                                    name    host_id  \
# 0                        Beautiful Loft/Appt Montmartre    2891527
# 1                        Beautiful Loft/Appt Montmartre    2891527
# 2                        Beautiful Loft/Appt Montmartre    2891527
# ...

# %%
'NaN' in my_df
# Out:
# False

# %%
my_df.isnull().sum()
# Out:
# listing_id                         0
# review_id                          0
# date                               0
# reviewer_id                        0
# name                              14
# host_id                            0
# host_since                         0
# host_location                      0
# host_response_time             39055
# host_response_rate             39055
# host_acceptance_rate           39055
# host_is_superhost                  0
# host_total_listings_count          0
# host_has_profile_pic               0
# host_identity_verified             0
# neighbourhood                      0
# district                       39055
# city                               0
# latitude                           0
# longitude                          0
# property_type                      0
# room_type                          0
# accommodates                       0
# bedrooms                           0
# amenities                          0
# ...

# %%
my_df.shape[0]
# Out:
# 39055

# %%
df2.isnull()
# Out:
#       listing_id   name  host_id  host_since  host_location  \
# 0          False  False    False       False          False
# 1          False  False    False       False          False
# 2          False  False    False       False          False
# 3          False  False    False       False          False
# 4          False  False    False       False          False
# ...          ...    ...      ...         ...            ...
# 4995       False  False    False       False          False
# 4996       False  False    False       False          False
# 4997       False  False    False       False          False
# 4998       False  False    False       False          False
# 4999       False  False    False       False          False
#
#       host_response_time  host_response_rate  host_acceptance_rate  \
# 0                   True                True                  True
# 1                   True                True                  True
# ...

# %%
df1.max(axis=0)
# Out:
# listing_id       48263869
# review_id       735623741
# date           2021-03-01
# reviewer_id     390338478
# dtype: object
# listing_id       48263869
# review_id       735623741
# date           2021-03-01
# reviewer_id     390338478
# dtype: object

# %%
df1[1:5]
# Out:
#    listing_id  review_id        date  reviewer_id
# 1       15383  330103585  2018-09-30     39147453
# 2       16455  329985788  2018-09-30      1125378
# 3       17919  330016899  2018-09-30    172717984
# 4       26827  329995638  2018-09-30     17542859

# %%
df2= np.array([[4, 5, 6],
                 [7, 8, 9]])
df2.T
# Out:
# array([[4, 7],
#        [5, 8],
#        [6, 9]])

# %%
df2.max(axis=1)
# Out:
# <ipython-input-126-f3852bee942d>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df2.max(axis=1)
# 0        1466919.0
# 1       10328771.0
# 2       19252768.0
# 3       10668311.0
# 4       24837558.0
#            ...
# 4995    78413936.0
# 4996    82441053.0
# 4997    33044986.0
# 4998    61390031.0
# 4999    60725339.0
# Length: 5000, dtype: float64

# %%
df1
# Out:
#          listing_id  review_id        date  reviewer_id
# 0             11798  330265172  2018-09-30     11863072
# 1             15383  330103585  2018-09-30     39147453
# 2             16455  329985788  2018-09-30      1125378
# 3             17919  330016899  2018-09-30    172717984
# 4             26827  329995638  2018-09-30     17542859
# ...             ...        ...         ...          ...
# 5373138    47779342  726766332  2021-01-25    283094516
# 5373139    47823964  727963021  2021-01-31     76411977
# 5373140    47896175  728548625  2021-02-02     71370946
# 5373141    47900451  727399287  2021-01-29    109011160
# 5373142    47998038  730320626  2021-02-11    276790978
#
# [5373143 rows x 4 columns]

# %%
len(df1.columns)
# Out:
# 4

# %%
df1.shape[0]
# Out:
# 5373143

# %%
df1.sample(5)
# Out:
#          listing_id  review_id        date  reviewer_id
# 4156727     6564097   77893064  2016-06-04     17313197
# 1263091    20174127  508844309  2019-08-13     43501808
# 2355308    14254645  223724701  2018-01-01     71207506
# 1998808    27598707  596379583  2020-01-22    328258913
# 5153002    17051107  181622886  2017-08-13    142994700

# %%
df1.groupby('date')['review_id'].agg(["sum"])
# Out:
#                     sum
# date
# 2008-11-16          282
# 2008-11-28          318
# 2009-01-21          562
# 2009-02-23          794
# 2009-04-23         1743
# ...                 ...
# 2021-02-25  54330392169
# 2021-02-26  72705420619
# 2021-02-27  26448024903
# 2021-02-28  20580950211
# 2021-03-01    735623741
#
# [4103 rows x 1 columns]

# %%
df1.groupby('date')['reviewer_id'].agg(["sum","min","max"])
# Out:
#                     sum        min        max
# date
# 2008-11-16         3734       3734       3734
# 2008-11-28         3726       3726       3726
# 2009-01-21         5120       5120       5120
# 2009-02-23         7671       7671       7671
# 2009-04-23         9868       9868       9868
# ...                 ...        ...        ...
# 2021-02-25  17171273572    3737915  389626657
# 2021-02-26  22636842751    7604643  389481114
# 2021-02-27   8329944907    2076974  390232384
# 2021-02-28   6326175880   44544938  390338478
# 2021-03-01    370437515  370437515  370437515
#
# [4103 rows x 3 columns]

# %%
df1.groupby('date')['reviewer_id'].agg(["max"])
# Out:
#                   max
# date
# 2008-11-16       3734
# 2008-11-28       3726
# 2009-01-21       5120
# 2009-02-23       7671
# 2009-04-23       9868
# ...               ...
# 2021-02-25  389626657
# 2021-02-26  389481114
# 2021-02-27  390232384
# 2021-02-28  390338478
# 2021-03-01  370437515
#
# [4103 rows x 1 columns]

# %%
df1.describe()
# Out:
#          listing_id     review_id   reviewer_id
# count  5.373143e+06  5.373143e+06  5.373143e+06
# mean   1.602989e+07  3.486753e+08  9.808133e+07
# std    1.198676e+07  2.061019e+08  9.080596e+07
# min    2.577000e+03  2.820000e+02  1.000000e+00
# 25%    5.332708e+06  1.666435e+08  2.390206e+07
# 50%    1.450814e+07  3.425727e+08  6.697814e+07
# 75%    2.414496e+07  5.334045e+08  1.528936e+08
# max    4.826387e+07  7.356237e+08  3.903385e+08

# %%
df1.head()
# Out:
#    listing_id  review_id        date  reviewer_id
# 0       11798  330265172  2018-09-30     11863072
# 1       15383  330103585  2018-09-30     39147453
# 2       16455  329985788  2018-09-30      1125378
# 3       17919  330016899  2018-09-30    172717984
# 4       26827  329995638  2018-09-30     17542859

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5373143 entries, 0 to 5373142
# Data columns (total 4 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   listing_id   int64
#  1   review_id    int64
#  2   date         object
#  3   reviewer_id  int64
# dtypes: int64(3), object(1)
# memory usage: 164.0+ MB

# %%
df1.columns
# Out:
# Index(['listing_id', 'review_id', 'date', 'reviewer_id'], dtype='object')

# %%
df1.dtypes
# Out:
# listing_id      int64
# review_id       int64
# date           object
# reviewer_id     int64
# dtype: object

# %%
import matplotlib.pyplot as plt

labels=["review_scores_checkin","review_scores_rating","review_scores_value","review_scores_cleanliness"]
data=[64651,622220,62246,61076]
plt.xticks=(range(len(labels)),data)
plt.xlabel('Reviewer data')
plt.ylabel('Reviewers')
plt.title('Statement of revisions')
plt.bar(range(len(data)),labels,color =("yellow","lightblue","Pink"))
plt.show()

# %%
import matplotlib.pyplot as plt
labels=["review_scores_checkin"],["review_scores_rating"],["review_scores_value"],["review_scores_cleanliness"]
data=[64651,622220,62246,61075]
plt.xticks=(range(len(data)),labels)
plt.xlabel('Reviewer data')
plt.ylabel('Reviewers')
plt.title('Statement of revisions')
plt.bar(range(len(data)),data,color =("green","brown","blue","yellow"))
plt.show()

# %%
import matplotlib.pyplot as plt
labels=["review_scores_rating"],["review_scores_value"],["review_scores_cleanliness"],["host_location"]
data=[23,44,56,66]

plt.xticks=(range(len(data)),labels)
plt.xlabel('data')
plt.ylabel('The ratio')
plt.title('Rating and reviews')
plt.bar(range(len(data)),data,color =['gold', 'yellowgreen', 'lightcoral', 'lightskyblue','orange','lightgrey'])
plt.show()

# %%
maximum_nights= np.random.poisson(100, 365)
minimum_nights= pd.Series(maximum_nights).rolling(window=7).mean()
plt.plot(minimum_nights, label='mini',color='blue')
plt.plot(maximum_nights, label='max', color='brown')
plt.legend()
plt.show()

# %% [markdown]
# Deliverables*
#
# We worked as follows:
# Imported
# On the page to get to know the whole body
# Then we uploaded the second file, the first analysis response, with the name df1, df2, and the link between them is my_df.
#  We showed that the site data contains more than 1000 columns and rows containing titles, values, and everything related to the host
# We worked as follows
# from :
# Delete, sort, calculate, larger than, smaller than, graphs from the highest rating and the cleanest rooms, then data science and colors for the eye, a clear statement, and we worked on [null, false, true]
# The largest and average accounts, etc.
# It was an enjoyable experience, and I ask God for success.
